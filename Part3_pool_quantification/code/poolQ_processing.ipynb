# %%
import os
import random
import pandas as pd
import numpy as np

# %%
input_folder = 'data/fig1_saturated'
output_folder = 'data/output'
poolQ_folder = 'data/poolQ'
ref_name = 'sgRNA_ref.csv'
condition_name = 'conditions.csv'

# %%
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
def run_poolQ(input_folder, poolQ_folder, ref_name, condition_name):
    
    # Use all fastq.gz files in the folder.
    listed_files = os.listdir(input_folder)
    fastq_file_names = [i for i in listed_files if 'fastq.gz' in i]
    template_seq = 'caccgNNNNNNNNNNNNNNNNNNNNgtttt'
    
    condition_path = os.path.join(input_folder, condition_name)
    ref_path = os.path.join(input_folder, ref_name)
    
    combined_res = pd.read_csv(ref_path, header=None)
    combined_res.columns = ['Row Barcode', 'Row Barcode IDs']

    for i in range(len(fastq_file_names)):
        file_name_1 = fastq_file_names[i]
        file_name_2 = file_name_1.replace("-", "_")
        name_split = file_name_2.split('_')
        ID = name_split[1]
        end_dir = name_split[2]
        short_name = '_'.join([end_dir, ID])
        
        # This is to run the command line
        fastq_path = os.path.join(input_folder, file_name_1)
        cmd = f'''{poolQ_folder}/poolq3.sh --reads {fastq_path} --col-reference {condition_path} --row-reference {ref_path} --row-barcode-policy TEMPLATE:{template_seq}@0 --col-barcode-policy FIXED:0'''
        # !{cmd}

        temp_res = pd.read_table('counts.txt', header=0)
        temp_res = temp_res[['Row Barcode', 'exp']]
        temp_res.columns = ['Row Barcode', short_name]
        combined_res = combined_res.merge(temp_res, on='Row Barcode', how='left')
    
    return combined_res

# %%
combined_res = run_poolQ(input_folder, poolQ_folder, ref_name, condition_name)
# Out:
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file49_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7419292846104611403
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 8757 ms (570.9718 reads/ms). Match percent: 96.42354; queue size: 100
# [INFO] Processed 10000000 reads in 16738 ms (597.44293 reads/ms). Match percent: 96.424; queue size: 100
# [INFO] Processed 15000000 reads in 24628 ms (609.06287 reads/ms). Match percent: 96.42765; queue size: 72
# [INFO] Processed 20000000 reads in 32537 ms (614.6848 reads/ms). Match percent: 96.42805; queue size: 100
# [INFO] Processed 25000000 reads in 40612 ms (615.5816 reads/ms). Match percent: 96.335655; queue size: 100
# [INFO] Processed 30000000 reads in 48651 ms (616.63684 reads/ms). Match percent: 96.27803; queue size: 70
# [INFO] Processed 35000000 reads in 56706 ms (617.2186 reads/ms). Match percent: 96.24048; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 38814958 reads in 62967 ms (616.43335 reads/ms). Match percent: 96.21627; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file33_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7134034886541983333
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9259 ms (540.01514 reads/ms). Match percent: 94.4577; queue size: 100
# [INFO] Processed 10000000 reads in 17746 ms (563.50726 reads/ms). Match percent: 94.48115; queue size: 100
# [INFO] Processed 15000000 reads in 26311 ms (570.10376 reads/ms). Match percent: 94.43448; queue size: 71
# [INFO] Shutting down.
# [INFO] Processed 17459396 reads in 30626 ms (570.0841 reads/ms). Match percent: 94.41862; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file17_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache3023263147495461355
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 10057 ms (497.16614 reads/ms). Match percent: 93.9981; queue size: 100
# [INFO] Processed 10000000 reads in 19343 ms (516.9829 reads/ms). Match percent: 94.04347; queue size: 100
# [INFO] Processed 15000000 reads in 28727 ms (522.15686 reads/ms). Match percent: 94.06896; queue size: 100
# [INFO] Processed 20000000 reads in 38100 ms (524.9344 reads/ms). Match percent: 94.05015; queue size: 78
# [INFO] Processed 25000000 reads in 47409 ms (527.32605 reads/ms). Match percent: 94.0218; queue size: 100
# [INFO] Processed 30000000 reads in 56749 ms (528.6437 reads/ms). Match percent: 94.01239; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 31152078 reads in 59017 ms (527.84924 reads/ms). Match percent: 94.004395; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file50_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7772816728333117018
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9553 ms (523.3958 reads/ms). Match percent: 96.06852; queue size: 100
# [INFO] Processed 10000000 reads in 18352 ms (544.8997 reads/ms). Match percent: 96.07117; queue size: 100
# [INFO] Processed 15000000 reads in 27079 ms (553.93475 reads/ms). Match percent: 96.0762; queue size: 54
# [INFO] Processed 20000000 reads in 35731 ms (559.73804 reads/ms). Match percent: 96.05354; queue size: 100
# [INFO] Processed 25000000 reads in 44502 ms (561.7725 reads/ms). Match percent: 95.97599; queue size: 100
# [INFO] Processed 30000000 reads in 53254 ms (563.33795 reads/ms). Match percent: 95.93063; queue size: 100
# [INFO] Processed 35000000 reads in 62103 ms (563.57983 reads/ms). Match percent: 95.89418; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 36372864 reads in 64610 ms (562.96027 reads/ms). Match percent: 95.88931; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file18_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7884634993680188712
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9793 ms (510.5688 reads/ms). Match percent: 94.42678; queue size: 100
# [INFO] Processed 10000000 reads in 18743 ms (533.53253 reads/ms). Match percent: 94.46606; queue size: 100
# [INFO] Processed 15000000 reads in 27756 ms (540.4237 reads/ms). Match percent: 94.46899; queue size: 100
# [INFO] Processed 20000000 reads in 36726 ms (544.5733 reads/ms). Match percent: 94.4172; queue size: 100
# [INFO] Processed 25000000 reads in 45707 ms (546.96216 reads/ms). Match percent: 94.39155; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 25571831 reads in 46835 ms (545.99835 reads/ms). Match percent: 94.38464; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file46_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache4363113703378866858
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9510 ms (525.7623 reads/ms). Match percent: 95.72642; queue size: 100
# [INFO] Processed 10000000 reads in 18304 ms (546.3287 reads/ms). Match percent: 95.72767; queue size: 100
# [INFO] Processed 15000000 reads in 27171 ms (552.0592 reads/ms). Match percent: 95.67975; queue size: 99
# [INFO] Shutting down.
# [INFO] Processed 15502176 reads in 28157 ms (550.5621 reads/ms). Match percent: 95.67005; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file41_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7610413714893359387
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9312 ms (536.9416 reads/ms). Match percent: 94.3334; queue size: 100
# [INFO] Processed 10000000 reads in 17779 ms (562.4613 reads/ms). Match percent: 94.36332; queue size: 100
# [INFO] Processed 15000000 reads in 26305 ms (570.2338 reads/ms). Match percent: 94.33461; queue size: 100
# [INFO] Processed 20000000 reads in 34864 ms (573.65765 reads/ms). Match percent: 94.3006; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 22988638 reads in 40133 ms (572.81134 reads/ms). Match percent: 94.28142; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file34_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7120923642876665837
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9957 ms (502.15927 reads/ms). Match percent: 94.30376; queue size: 100
# [INFO] Processed 10000000 reads in 19117 ms (523.0946 reads/ms). Match percent: 94.30835; queue size: 100
# [INFO] Processed 15000000 reads in 28282 ms (530.3727 reads/ms). Match percent: 94.23918; queue size: 87
# [INFO] Shutting down.
# [INFO] Processed 18623470 reads in 35051 ms (531.32495 reads/ms). Match percent: 94.19636; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file40_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7475569880306948351
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9733 ms (513.71625 reads/ms). Match percent: 94.49088; queue size: 100
# [INFO] Processed 10000000 reads in 18743 ms (533.53253 reads/ms). Match percent: 94.52742; queue size: 100
# [INFO] Processed 15000000 reads in 27755 ms (540.4432 reads/ms). Match percent: 94.47168; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 18765066 reads in 34646 ms (541.62286 reads/ms). Match percent: 94.441345; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file23_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache1499919833224529669
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 10013 ms (499.35083 reads/ms). Match percent: 95.95652; queue size: 100
# [INFO] Processed 10000000 reads in 19286 ms (518.51086 reads/ms). Match percent: 96.01236; queue size: 100
# [INFO] Processed 15000000 reads in 28515 ms (526.03894 reads/ms). Match percent: 96.032845; queue size: 69
# [INFO] Processed 20000000 reads in 37729 ms (530.0962 reads/ms). Match percent: 95.989624; queue size: 100
# [INFO] Processed 25000000 reads in 47009 ms (531.81305 reads/ms). Match percent: 95.97627; queue size: 92
# [INFO] Shutting down.
# [INFO] Processed 28661572 reads in 53893 ms (531.82367 reads/ms). Match percent: 95.95825; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file35_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache886066411851230348
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9673 ms (516.9027 reads/ms). Match percent: 94.99454; queue size: 100
# [INFO] Processed 10000000 reads in 18568 ms (538.561 reads/ms). Match percent: 95.03289; queue size: 100
# [INFO] Processed 15000000 reads in 27399 ms (547.4652 reads/ms). Match percent: 94.97237; queue size: 83
# [INFO] Shutting down.
# [INFO] Processed 17767196 reads in 32440 ms (547.6941 reads/ms). Match percent: 94.95683; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file48_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache6761533128531079897
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 10011 ms (499.4506 reads/ms). Match percent: 95.8842; queue size: 100
# [INFO] Processed 10000000 reads in 19351 ms (516.76917 reads/ms). Match percent: 95.92199; queue size: 100
# [INFO] Processed 15000000 reads in 28675 ms (523.10376 reads/ms). Match percent: 95.93367; queue size: 88
# [INFO] Processed 20000000 reads in 38041 ms (525.74854 reads/ms). Match percent: 95.89233; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 24877100 reads in 47260 ms (526.38806 reads/ms). Match percent: 95.877205; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file24_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache5120946695215248626
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9935 ms (503.27127 reads/ms). Match percent: 96.05346; queue size: 100
# [INFO] Processed 10000000 reads in 19093 ms (523.75214 reads/ms). Match percent: 96.09646; queue size: 100
# [INFO] Processed 15000000 reads in 28271 ms (530.57904 reads/ms). Match percent: 96.10749; queue size: 100
# [INFO] Processed 20000000 reads in 37434 ms (534.2737 reads/ms). Match percent: 96.06578; queue size: 80
# [INFO] Processed 25000000 reads in 46633 ms (536.1011 reads/ms). Match percent: 96.0357; queue size: 100
# [INFO] Processed 30000000 reads in 55835 ms (537.2974 reads/ms). Match percent: 96.00694; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 30403599 reads in 56679 ms (536.41736 reads/ms). Match percent: 96.002304; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file47_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7398345893873080841
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 8940 ms (559.2841 reads/ms). Match percent: 95.44042; queue size: 100
# [INFO] Processed 10000000 reads in 17274 ms (578.9047 reads/ms). Match percent: 95.48214; queue size: 100
# [INFO] Processed 15000000 reads in 25710 ms (583.43054 reads/ms). Match percent: 95.42099; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 19861782 reads in 34088 ms (582.662 reads/ms). Match percent: 95.37784; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file42_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache3294921948511063980
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9597 ms (520.99615 reads/ms). Match percent: 94.30058; queue size: 100
# [INFO] Processed 10000000 reads in 18384 ms (543.95123 reads/ms). Match percent: 94.34099; queue size: 100
# [INFO] Processed 15000000 reads in 27209 ms (551.28815 reads/ms). Match percent: 94.28114; queue size: 67
# [INFO] Processed 20000000 reads in 36055 ms (554.70807 reads/ms). Match percent: 94.25651; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 20690464 reads in 37373 ms (553.6206 reads/ms). Match percent: 94.24718; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file38_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7284912644107704629
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9366 ms (533.8458 reads/ms). Match percent: 95.79744; queue size: 100
# [INFO] Processed 10000000 reads in 17835 ms (560.69525 reads/ms). Match percent: 95.82737; queue size: 100
# [INFO] Processed 15000000 reads in 26374 ms (568.74194 reads/ms). Match percent: 95.83004; queue size: 100
# [INFO] Processed 20000000 reads in 34907 ms (572.951 reads/ms). Match percent: 95.776115; queue size: 83
# [INFO] Processed 25000000 reads in 43471 ms (575.09607 reads/ms). Match percent: 95.7472; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 26674760 reads in 46463 ms (574.10754 reads/ms). Match percent: 95.73084; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file37_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache5055379057288530783
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9490 ms (526.87036 reads/ms). Match percent: 96.34662; queue size: 100
# [INFO] Processed 10000000 reads in 18320 ms (545.8515 reads/ms). Match percent: 96.39077; queue size: 100
# [INFO] Processed 15000000 reads in 27127 ms (552.95465 reads/ms). Match percent: 96.40871; queue size: 100
# [INFO] Processed 20000000 reads in 35948 ms (556.3592 reads/ms). Match percent: 96.36685; queue size: 100
# [INFO] Processed 25000000 reads in 44864 ms (557.2397 reads/ms). Match percent: 96.34719; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 28789099 reads in 51632 ms (557.5825 reads/ms). Match percent: 96.331055; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file13_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache1885142179060629948
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9924 ms (503.8291 reads/ms). Match percent: 95.51866; queue size: 100
# [INFO] Processed 10000000 reads in 19117 ms (523.0946 reads/ms). Match percent: 95.56765; queue size: 100
# [INFO] Processed 15000000 reads in 28316 ms (529.73584 reads/ms). Match percent: 95.560905; queue size: 94
# [INFO] Processed 20000000 reads in 37557 ms (532.5239 reads/ms). Match percent: 95.521286; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 23617514 reads in 44298 ms (533.1508 reads/ms). Match percent: 95.50503; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file14_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache8989281692946760966
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9416 ms (531.01105 reads/ms). Match percent: 96.08914; queue size: 100
# [INFO] Processed 10000000 reads in 18081 ms (553.0668 reads/ms). Match percent: 96.1471; queue size: 100
# [INFO] Processed 15000000 reads in 26737 ms (561.0203 reads/ms). Match percent: 96.14218; queue size: 68
# [INFO] Processed 20000000 reads in 35410 ms (564.8122 reads/ms). Match percent: 96.08247; queue size: 100
# [INFO] Processed 25000000 reads in 44118 ms (566.6621 reads/ms). Match percent: 96.057236; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 25666532 reads in 45377 ms (565.62866 reads/ms). Match percent: 96.049034; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file45_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache1033121722335547111
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 10585 ms (472.36655 reads/ms). Match percent: 95.54112; queue size: 100
# [INFO] Processed 10000000 reads in 20404 ms (490.09998 reads/ms). Match percent: 95.56614; queue size: 100
# [INFO] Processed 15000000 reads in 30189 ms (496.86972 reads/ms). Match percent: 95.49786; queue size: 75
# [INFO] Shutting down.
# [INFO] Processed 18394096 reads in 36919 ms (498.22845 reads/ms). Match percent: 95.466125; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file28_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache3484831286462210709
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 8906 ms (561.41925 reads/ms). Match percent: 95.40924; queue size: 100
# [INFO] Processed 10000000 reads in 17117 ms (584.21454 reads/ms). Match percent: 95.41726; queue size: 100
# [INFO] Processed 15000000 reads in 25331 ms (592.1598 reads/ms). Match percent: 95.43259; queue size: 100
# [INFO] Processed 20000000 reads in 33511 ms (596.819 reads/ms). Match percent: 95.45126; queue size: 100
# [INFO] Processed 25000000 reads in 41778 ms (598.40106 reads/ms). Match percent: 95.4327; queue size: 100
# [INFO] Processed 30000000 reads in 50062 ms (599.2569 reads/ms). Match percent: 95.39768; queue size: 100
# [INFO] Processed 35000000 reads in 58434 ms (598.9664 reads/ms). Match percent: 95.3833; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 39913071 reads in 66777 ms (597.70685 reads/ms). Match percent: 95.36576; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file44_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache6074198179869536606
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 10326 ms (484.2146 reads/ms). Match percent: 95.0826; queue size: 100
# [INFO] Processed 10000000 reads in 19947 ms (501.32852 reads/ms). Match percent: 95.09782; queue size: 100
# [INFO] Processed 15000000 reads in 29563 ms (507.391 reads/ms). Match percent: 95.0443; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 16021399 reads in 31632 ms (506.49338 reads/ms). Match percent: 95.02868; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file27_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache216540036653970804
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9693 ms (515.8362 reads/ms). Match percent: 94.87416; queue size: 100
# [INFO] Processed 10000000 reads in 18587 ms (538.01044 reads/ms). Match percent: 94.9307; queue size: 100
# [INFO] Processed 15000000 reads in 27462 ms (546.2093 reads/ms). Match percent: 94.94924; queue size: 100
# [INFO] Processed 20000000 reads in 36328 ms (550.53955 reads/ms). Match percent: 94.90916; queue size: 100
# [INFO] Processed 25000000 reads in 45197 ms (553.13403 reads/ms). Match percent: 94.888985; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 28112843 reads in 50870 ms (552.6409 reads/ms). Match percent: 94.87366; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file39_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache4772195986677630389
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9909 ms (504.5918 reads/ms). Match percent: 94.83854; queue size: 100
# [INFO] Processed 10000000 reads in 18878 ms (529.7171 reads/ms). Match percent: 94.86107; queue size: 100
# [INFO] Processed 15000000 reads in 27789 ms (539.7819 reads/ms). Match percent: 94.81546; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 18525303 reads in 34262 ms (540.6954 reads/ms). Match percent: 94.796844; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file43_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache7098487336497195608
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9547 ms (523.72473 reads/ms). Match percent: 95.25306; queue size: 100
# [INFO] Processed 10000000 reads in 18133 ms (551.4807 reads/ms). Match percent: 95.27645; queue size: 100
# [INFO] Processed 15000000 reads in 26763 ms (560.4753 reads/ms). Match percent: 95.218285; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 18381329 reads in 32703 ms (562.06854 reads/ms). Match percent: 95.19596; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete
# [INFO] PoolQ runtime configuration summary
# Input files:
# 	Conditions file:	data/fig2_global_CYS063/conditions.csv
# 	Reference file:	data/fig2_global_CYS063/CYS063_ref.csv
# 	Reads file:	data/fig2_global_CYS063/global_file36_R1_001.fastq.gz
# Row barcode match function:	mismatch
# Column barcode match function:	exact
# Row barcode policy:	TEMPLATE:caccgNNNNNNNNNNNNNNNNNNNNgtttt@0
# Col barcode policy:	FIXED:0
#
# [INFO] Reading row reference data
# [INFO] Reading column reference data
# [INFO] Reading global reference data
# [INFO] Building row reference
# [INFO] Building column reference
# [INFO] Writing unexpected sequence cache files to /var/folders/py/mpy80_vj2lgg0bk277c880t80000gn/T/unexpected-sequence-cache1468151972286121118
# [INFO] Beginning task processing.
# [INFO] Processed 5000000 reads in 9977 ms (501.15265 reads/ms). Match percent: 95.12028; queue size: 100
# [INFO] Processed 10000000 reads in 19202 ms (520.7791 reads/ms). Match percent: 95.16357; queue size: 100
# [INFO] Processed 15000000 reads in 28430 ms (527.6117 reads/ms). Match percent: 95.11288; queue size: 100
# [INFO] Shutting down.
# [INFO] Processed 19007310 reads in 35968 ms (528.45056 reads/ms). Match percent: 95.087746; queue size: 0
# [INFO] Writing counts file counts.txt
# [INFO] Writing quality file quality.txt
# [INFO] Writing log-normalized counts file lognormalized-counts.txt
# [INFO] Writing barcode counts file barcode-counts.txt
# [INFO] Writing correlation file correlation.txt
# [WARN] Skipping correlation file for trivial dataset (1 columns and 23995 rows)
# [INFO] Writing unexpected sequence report unexpected-sequences.txt
# [INFO] Writing run info unexpected-sequences.txt
# [INFO] PoolQ complete

# %%
combined_res
# Out:
#                 Row Barcode Row Barcode IDs  R1_file49  R1_file33  R1_file17  \
# 0      TACGTCATTAAGAGTTCAAC    NO_CURRENT_2       1342        151        480
# 1      GATTCATACTAAACACTCTA    NO_CURRENT_3       1325        197        594
# 2      ATCTTCTCGACGAAAATGCG    NO_CURRENT_4       1691        374        839
# 3      GAGCTGGACGGCGACGTAAA    NO_CURRENT_5       9022       3521       3075
# 4      AATTGTCTTGTCCCTATCGA    NO_CURRENT_6       1438        926       1444
# ...                     ...             ...        ...        ...        ...
# 23995  CACATTTGATTGCTTCCTCT        EIF2S1_2       1497        755        937
# 23996  CACACTCATTCCTGCCAATT        EIF2S1_3       1095        230        615
# 23997  CCGGTGGCAACCCTTAGGGC         NELFE_0       1026        543        829
# 23998  GGCAACCCTTAGGGCTGTTC         NELFE_1       1436        661       1266
# 23999  GAAGGCACAGCTGGGATAAG         NELFE_2       1411        629       1345
#
#        R1_file50  R1_file18  R1_file46  R1_file41  R1_file34  ...  R1_file37  \
# 0            889        735        837        620        340  ...        883
# 1            801        650        121        559        248  ...       1336
# 2           1514       1313        941        367        475  ...       1091
# 3          13920       2156       2687       7891       5345  ...       8256
# 4           1475       1215        482        640       1078  ...       1427
# ...          ...        ...        ...        ...        ...  ...        ...
# 23995       1457        952        408        759        423  ...       1150
# 23996       1218        785        826       1507        685  ...       1056
# 23997        960        456         93        787        418  ...        886
# 23998       1423        998        328        671        739  ...        999
# 23999       1891       1653        736        939        566  ...       1280
#
#        R1_file13  R1_file14  R1_file45  R1_file28  R1_file44  R1_file27  \
# 0            552        750       1538        484        112        396
# 1            394        812        102        864        302        574
# 2            810       1315        918       1264        364        530
# 3           1283       1524       4216       7311       2847       2190
# 4            888       1087        593       1050        371       1548
# ...          ...        ...        ...        ...        ...        ...
# 23995        705        944        528        883        449        790
# 23996        658        913        807       1411       2452        424
# 23997        365        503        155        676        228        576
# 23998        595        743        516        704        198        780
# 23999       1066       1156        634       1026        629       1148
#
#        R1_file39  R1_file43  R1_file36
# 0            253        207        210
# 1            220        163        315
# 2            432        261        499
# 3           3581       5700       2549
# 4            904        568        427
# ...          ...        ...        ...
# 23995        709        462        970
# 23996        523        223        633
# 23997        279        262        410
# 23998        623        945        995
# 23999        890       1575       1043
#
# [24000 rows x 28 columns]

# %%
# save results
combined_res.to_csv(os.path.join(output_folder, 'fig1_poolQ_result.csv'))
